# %% [markdown]
# <a href="https://colab.research.google.com/github/cookieeyoung/ML-project1/blob/main/EDA_(1)_%EC%A3%BC%EC%97%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 라이브러리 로드
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression


# 불필요한 경고문 생략(선택)
import warnings
warnings.filterwarnings('ignore')

# 모든 컬럼 출력설정(선택)
pd.set_option('display.max_columns', None)

# 데이터 로드
df = pd.read_csv('/content/drive/MyDrive/심화프로젝트 ML/Churn_Modelling.csv')
df
# Out:
#        RowNumber  CustomerId    Surname  CreditScore Geography  Gender   Age  \
# 0              1    15634602   Hargrave          619    France  Female  42.0
# 1              2    15647311       Hill          608     Spain  Female  41.0
# 2              3    15619304       Onio          502    France  Female  42.0
# 3              4    15701354       Boni          699    France  Female  39.0
# 4              5    15737888   Mitchell          850     Spain  Female  43.0
# ...          ...         ...        ...          ...       ...     ...   ...
# 9997        9998    15584532        Liu          709    France  Female  36.0
# 9998        9999    15682355  Sabbatini          772   Germany    Male  42.0
# 9999        9999    15682355  Sabbatini          772   Germany    Male  42.0
# 10000      10000    15628319     Walker          792    France  Female  28.0
# 10001      10000    15628319     Walker          792    France  Female  28.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10002 entries, 0 to 10001
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10002 non-null  int64
#  1   CustomerId       10002 non-null  int64
#  2   Surname          10002 non-null  object
#  3   CreditScore      10002 non-null  int64
#  4   Geography        10001 non-null  object
#  5   Gender           10002 non-null  object
#  6   Age              10001 non-null  float64
#  7   Tenure           10002 non-null  int64
#  8   Balance          10002 non-null  float64
#  9   NumOfProducts    10002 non-null  int64
#  10  HasCrCard        10001 non-null  float64
#  11  IsActiveMember   10001 non-null  float64
#  12  EstimatedSalary  10002 non-null  float64
#  13  Exited           10002 non-null  int64
# dtypes: float64(5), int64(6), object(3)
# memory usage: 1.1+ MB

# %%
#결측치 확인
df.isnull().sum()

#결측치 제거
not_null_data = df.dropna()
not_null_data
# Out:
#        RowNumber  CustomerId    Surname  CreditScore Geography  Gender   Age  \
# 0              1    15634602   Hargrave          619    France  Female  42.0
# 1              2    15647311       Hill          608     Spain  Female  41.0
# 2              3    15619304       Onio          502    France  Female  42.0
# 3              4    15701354       Boni          699    France  Female  39.0
# 5              6    15574012        Chu          645     Spain    Male  44.0
# ...          ...         ...        ...          ...       ...     ...   ...
# 9997        9998    15584532        Liu          709    France  Female  36.0
# 9998        9999    15682355  Sabbatini          772   Germany    Male  42.0
# 9999        9999    15682355  Sabbatini          772   Germany    Male  42.0
# 10000      10000    15628319     Walker          792    France  Female  28.0
# 10001      10000    15628319     Walker          792    France  Female  28.0
#
# ...

# %%
#중복값제거
new_data = not_null_data.drop_duplicates()
new_data
# Out:
#        RowNumber  CustomerId    Surname  CreditScore Geography  Gender   Age  \
# 0              1    15634602   Hargrave          619    France  Female  42.0
# 1              2    15647311       Hill          608     Spain  Female  41.0
# 2              3    15619304       Onio          502    France  Female  42.0
# 3              4    15701354       Boni          699    France  Female  39.0
# 5              6    15574012        Chu          645     Spain    Male  44.0
# ...          ...         ...        ...          ...       ...     ...   ...
# 9995        9996    15606229   Obijiaku          771    France    Male  39.0
# 9996        9997    15569892  Johnstone          516    France    Male  35.0
# 9997        9998    15584532        Liu          709    France  Female  36.0
# 9998        9999    15682355  Sabbatini          772   Germany    Male  42.0
# 10000      10000    15628319     Walker          792    France  Female  28.0
#
# ...

# %%
plt.boxplot(new_data['CreditScore'])
plt.show()

# %%
#데이터 이상치 처리
#Q1,Q3
Q1 = new_data['CreditScore'].quantile(0.25)
Q3 = new_data['CreditScore'].quantile(0.75)

#IQR
IQR = Q3 - Q1

lower_bound = Q1 - 1.5*IQR
upper_bound = Q3 + 1.5*IQR

#이상치 제거
cleansed_data = new_data[(new_data['CreditScore'] >= lower_bound) & (new_data['CreditScore'] <= upper_bound)]
cleansed_data
# Out:
#        RowNumber  CustomerId    Surname  CreditScore Geography  Gender   Age  \
# 0              1    15634602   Hargrave          619    France  Female  42.0
# 1              2    15647311       Hill          608     Spain  Female  41.0
# 2              3    15619304       Onio          502    France  Female  42.0
# 3              4    15701354       Boni          699    France  Female  39.0
# 5              6    15574012        Chu          645     Spain    Male  44.0
# ...          ...         ...        ...          ...       ...     ...   ...
# 9995        9996    15606229   Obijiaku          771    France    Male  39.0
# 9996        9997    15569892  Johnstone          516    France    Male  35.0
# 9997        9998    15584532        Liu          709    France  Female  36.0
# 9998        9999    15682355  Sabbatini          772   Germany    Male  42.0
# 10000      10000    15628319     Walker          792    France  Female  28.0
#
# ...

# %%
cleansed_data.describe()
# Out:
#           RowNumber    CustomerId  CreditScore          Age       Tenure  \
# count   9980.000000  9.980000e+03  9980.000000  9980.000000  9980.000000
# mean    5003.166333  1.569090e+07   650.964729    38.913530     5.014429
# std     2884.447154  7.192688e+04    96.010615    10.488229     2.891669
# min        1.000000  1.556570e+07   386.000000    18.000000     0.000000
# 25%     2507.750000  1.562850e+07   584.000000    32.000000     3.000000
# 50%     5003.500000  1.569073e+07   652.000000    37.000000     5.000000
# 75%     7499.250000  1.575318e+07   718.000000    44.000000     8.000000
# max    10000.000000  1.581569e+07   850.000000    92.000000    10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count    9980.000000    9980.000000  9980.000000     9980.000000
# mean    76459.865667       1.530261     0.705311        0.515331
# std     62397.571059       0.580943     0.455926        0.499790
# ...

# %%
#나이 그룹화- 이탈고객 상관관계 분석
cleansed_data['Age_group'] = (cleansed_data['Age']//10) * 10
cleansed_data

exit1 = cleansed_data[cleansed_data['Exited']==1]
exit1
